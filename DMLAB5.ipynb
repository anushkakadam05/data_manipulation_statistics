# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/Retail_Dataset_Cleaned (1).csv")
print("Dataset loaded successfully")
# Out:
# Dataset loaded successfully

# %%
df.head()
# Out:
#          Store_ID                      Store_Name    Brand_Name    Store_Type  \
# 0     Bx_Pune_034    Brandx_India Superstore Pune  Brandx_India      Flagship
# 1   Bx_Mumbai_023  Brandx_India Superstore Mumbai  Brandx_India  Street Store
# 2     Bx_Pune_073        Brandx_India Trends Pune  Brandx_India      Flagship
# 3  Bx_Chennai_061     Brandx_India Trends Chennai  Brandx_India    Mall Store
# 4  Bx_Chennai_033    Brandx_India Connect Chennai  Brandx_India    Mall Store
#
#       City City_Tier     Product_Name   Category     Sub_Category  \
# 0     Pune     Tier1   Green Tea 100G  Groceries              Tea
# 1   Mumbai     Metro  White Sugar 1Kg  Groceries            Sugar
# 2     Pune     Tier1   Levi'S T-Shirt    Clothes         T-Shirts
# 3  Chennai     Metro    Adidas Hoodie    Clothes          Jackets
# 4  Chennai     Metro    Playstation 5    Gadgets  Gaming Consoles
#
#   Product_Stage  ...  Brand_Loyalty  Brand_Awareness  Price_Competitiveness  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5146 entries, 0 to 5145
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Store_ID               5146 non-null   object
#  1   Store_Name             5146 non-null   object
#  2   Brand_Name             5146 non-null   object
#  3   Store_Type             5146 non-null   object
#  4   City                   5146 non-null   object
#  5   City_Tier              5146 non-null   object
#  6   Product_Name           5146 non-null   object
#  7   Category               5146 non-null   object
#  8   Sub_Category           5146 non-null   object
#  9   Product_Stage          5146 non-null   object
#  10  Quantity_Available     5146 non-null   float64
#  11  Units_Sold             5146 non-null   float64
#  12  Unit_Price             5146 non-null   int64
#  13  Cost_Price             5146 non-null   int64
# ...

# %%
df["Profit_Amount"] = (df["Revenue"] * df["Profit_Margin"] / 100 )
df[["Revenue","Profit_Margin","Profit_Amount"]].sample(5)
# Out:
#         Revenue  Profit_Margin  Profit_Amount
# 971    256732.0          23.66     60742.7912
# 2318  2252184.0          16.47    370934.7048
# 4469  3638842.0          22.81    830019.8602
# 3847   350176.0          22.28     78019.2128
# 4147   108832.0          18.02     19611.5264

# %%
df["Stock_Difference"] = (df["Quantity_Available"] - df["Units_Sold"])
df[["Quantity_Available","Units_Sold","Stock_Difference"]].sample(5)
# Out:
#       Quantity_Available  Units_Sold  Stock_Difference
# 3815                82.0        39.0              43.0
# 350                 78.0        39.0              39.0
# 1124               173.0        60.0             113.0
# 1697               181.0       117.0              64.0
# 3606                85.0        17.0              68.0

# %%
df["Inventory_Status"] = np.where(df["Quantity_Available"] < 100, "Low Stock", np.where(df["Quantity_Available"] <= 200, "Medium Stock","High Stock"))
df[["Quantity_Available","Inventory_Status"]].sample(5)
# Out:
#       Quantity_Available Inventory_Status
# 4344               166.0     Medium Stock
# 4888                64.0        Low Stock
# 3030               131.0     Medium Stock
# 3834               172.0     Medium Stock
# 70                  69.0        Low Stock

# %%
df["Revenue_Per_Unit"] = df["Revenue"] / df["Units_Sold"]
df[["Revenue","Units_Sold","Revenue_Per_Unit"]].sample(5)
# Out:
#          Revenue  Units_Sold  Revenue_Per_Unit
# 3167    113212.0        31.0            3652.0
# 5036    134184.0         8.0           16773.0
# 3318  17938908.0        78.0          229986.0
# 1300   4018960.0        16.0          251185.0
# 4894    171675.0         7.0           24525.0

# %%
print(df[["Profit_Amount","Stock_Difference","Inventory_Status","Revenue_Per_Unit"]].head())
# Out:
#    Profit_Amount  Stock_Difference Inventory_Status  Revenue_Per_Unit
# 0      1584.0480             101.0     Medium Stock             305.0
# 1       490.0455             100.0     Medium Stock              47.0
# 2     13175.1240             184.0       High Stock            2140.0
# 3     14080.1628             141.0     Medium Stock            3534.0
# 4    398237.3460             128.0     Medium Stock           50676.0

# %%
df["Revenue_Category"] = np.where (df["Revenue"] < 5000,"Low Revenue", np.where(df["Revenue"] < 10000,"Medium Revenue","High Revenue"))
df[["Revenue","Revenue_Category"]].head()
# Out:
#      Revenue Revenue_Category
# 0     7320.0   Medium Revenue
# 1     1645.0      Low Revenue
# 2    66340.0     High Revenue
# 3    77748.0     High Revenue
# 4  1976364.0     High Revenue

# %%
df["Customer_Feedback"] = np.where(
    df["Customer_Satisfaction"] >= 4,
    "Satisfied",
    "Needs Improvement"
)

df[[
    "Customer_Satisfaction",
    "Customer_Feedback"
]].head()
# Out:
#    Customer_Satisfaction  Customer_Feedback
# 0                    4.0          Satisfied
# 1                    3.9  Needs Improvement
# 2                    4.3          Satisfied
# 3                    4.4          Satisfied
# 4                    3.9  Needs Improvement

# %%
df["Discount_Category"] = np.where(
    df["Max_Discount_Offered"] < 10,
    "Low Discount",
    np.where(
        df["Max_Discount_Offered"] < 20,
        "Medium Discount",
        "High Discount"
    )
)

df[["Max_Discount_Offered", "Discount_Category"]].sample(5)
# Out:
#       Max_Discount_Offered Discount_Category
# 1463                     0      Low Discount
# 1450                     0      Low Discount
# 256                     11   Medium Discount
# 3850                    35     High Discount
# 2184                    26     High Discount

# %%
df["Delivery_Speed"] = np.where(
    df["Delivery_Time"] <= 5,
    "Fast Delivery",
    "Standard Delivery"
)

df[[
    "Delivery_Time",
    "Delivery_Speed"
]].head()
# Out:
#    Delivery_Time     Delivery_Speed
# 0            6.0  Standard Delivery
# 1            4.0      Fast Delivery
# 2            4.0      Fast Delivery
# 3            5.0      Fast Delivery
# 4            2.0      Fast Delivery

# %%
print(df[[
    "Revenue_Category",
    "Customer_Feedback",
    "Discount_Category",
    "Delivery_Speed"
]].head())
# Out:
#   Revenue_Category  Customer_Feedback Discount_Category     Delivery_Speed
# 0   Medium Revenue          Satisfied      Low Discount  Standard Delivery
# 1      Low Revenue  Needs Improvement     High Discount      Fast Delivery
# 2     High Revenue          Satisfied     High Discount      Fast Delivery
# 3     High Revenue          Satisfied     High Discount      Fast Delivery
# 4     High Revenue  Needs Improvement     High Discount      Fast Delivery

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5146 entries, 0 to 5145
# Data columns (total 55 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Store_ID               5146 non-null   object
#  1   Store_Name             5146 non-null   object
#  2   Brand_Name             5146 non-null   object
#  3   Store_Type             5146 non-null   object
#  4   City                   5146 non-null   object
#  5   City_Tier              5146 non-null   object
#  6   Product_Name           5146 non-null   object
#  7   Category               5146 non-null   object
#  8   Sub_Category           5146 non-null   object
#  9   Product_Stage          5146 non-null   object
#  10  Quantity_Available     5146 non-null   float64
#  11  Units_Sold             5146 non-null   float64
#  12  Unit_Price             5146 non-null   int64
#  13  Cost_Price             5146 non-null   int64
# ...
